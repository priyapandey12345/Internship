# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Required libraries need to be imported

# %%
df= pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# Read the csv file to get the dataset

# %%
df.shape
# Out:
# (30, 17)

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Checking the shape & describing the dataset

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# checking the null values from the dataset

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %% [markdown]
# We are checking the head & tail of the dataset

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical Columns: ", categorical_col)
print("\n")

numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical Columns: ", numerical_col)
# Out:
# Categorical Columns:  []
#
#
# Numerical Columns:  ['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA', 'CG', 'SHO', 'SV', 'E']

# %% [markdown]
# Need to check the categorical & numerical data present in the dataset. Here we can see that there is no categorical data is present

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Using the heatmap to represent the dataset t verify the null values

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Checking the skewness in the dataset

# %%
df['R'] = np.cbrt(df['R'])

# %%
df.skew()
# Out:
# W      0.047089
# R      0.892970
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor= "green")
plotnumber=1
for col in df:
    if plotnumber<=10:
        ax=plt.subplot(2,5,plotnumber)
        sns.distplot(df[col], color="m")
        plt.xlabel(col, fontsize = 14)
        plt.yticks(rotation=0, fontsize=10)
        plotnumber+=1
        plt.tight_layout()

# %% [markdown]
# Representing the dataset with distplot to check the skewness of the dataset

# %%
plt.figure(figsize=(10,6), facecolor= 'white')
plotnumber=1
for col in df:
    if plotnumber<=10:
        ax=plt.subplot(2,5, plotnumber)
        sns.boxplot(df[col], palette="Set2_r")
        plt.xlabel(col, fontsize=15)
        plt.yticks(rotation=0, fontsize=10)
        plotnumber+=1
    plt.tight_layout()

# %% [markdown]
# Using boxplot to check the skewness & outliers in the dataset

# %%
ax=sns.countplot(x='AB', data=df)
print(df['AB'].value_counts())
# Out:
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: AB, dtype: int64

# %% [markdown]
# Created the countplot of the dataset

# %%
cor= df.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.439027 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.439027  1.000000  0.332282  0.483362  0.564836 -0.053415  0.675069
# AB  -0.087947  0.332282  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.483362  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.564836  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.053415  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.675069 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.398238 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.038776 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081242  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.048267  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.046518  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %% [markdown]
# Need to check the correlation of the dataset

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), linewidths=0.1, fmt=".1g", linecolor="black", annot= True, cmap= "Blues_r")
plt.yticks(rotation=0);
plt.show()

# %% [markdown]
# Created the heatmap to show the correlation between the dataset

# %%
x=df.drop("W", axis=1)
y=df["W"]

# %% [markdown]
# Here we have to drop the target variable

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.650959  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1   0.164710 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2  -0.316685 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3  -1.186544  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4   0.041117  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
# 5   3.317778 -0.104884  1.361089  1.869832 -1.391501  2.185047  1.798742
# 6   1.324315  0.732263 -0.116292 -0.153633 -1.196885  1.545833  1.513510
# 7   0.461454 -0.451289 -0.596886 -1.615025 -1.099578  1.705636 -0.910958
# 8  -0.774111 -0.451289 -0.365489  0.183611  0.068115  0.107601 -0.590073
# 9   1.057861  1.785913  1.628086  1.082929  0.165423 -0.084163  0.158660
# 10  1.108108 -0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.736464 -0.826562 -0.721484  0.183611 -0.515731  2.121125  0.301276
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared (R2) Score: {r2}')
# Out:
# Mean Squared Error: 25.20480395747659
# R-squared (R2) Score: 0.808449874927347

# %% [markdown]
# Created the model in our dataset

# %%
import joblib
joblib.dump(model,"W.pkl")
# Out:
# ['W.pkl']

# %%
model = joblib.load("W.pkl")
prediction = model.predict(X_test)
prediction
# Out:
# array([82.93107139, 99.8601858 , 68.18997933, 92.79587469, 90.71206173,
#        79.38454559])

# %%
a = np.array(y_test) 
df = pd.DataFrame()
df["Predicted"] = prediction
df["Original"]=a
df
# Out:
#    Predicted  Original
# 0  82.931071        79
# 1  99.860186       100
# 2  68.189979        67
# 3  92.795875        97
# 4  90.712062        80
# 5  79.384546        78

# %% [markdown]
# Now we have predicted the target variable
